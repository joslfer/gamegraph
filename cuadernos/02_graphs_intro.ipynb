# %%
# %load_ext autoreload 
# %autoreload 2

# %%
import sys

sys.path.append("../src")

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Network Topologies

# %% [markdown]
# ## Normal network

# %%
G = nx.Graph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,2),(4,5),(3,2),(3,1)]) #accepts a tuple list


nx.draw(G, with_labels = True)
plt.show()

# %% [markdown]
# ## Erdős–Rényi Random Graph

# %%
G1 = nx.erdos_renyi_graph(10, 0.3, seed = 67)
nx.draw(G1,with_labels=True)

# %% [markdown]
# ## Grid (Lattice)

# %%
G_lattice = nx.grid_2d_graph(3, 8)
nx.draw(G_lattice,with_labels=True)

# %% [markdown]
# ## Watts–Strogatz Small-World Network

# %%
G_strogatz = nx.watts_strogatz_graph(10,4,0.1, seed=67)
nx.draw(G_strogatz)
plt.show()

# %% [markdown]
# ## Barabási–Albert Scale-Free Network

# %%
G_hubs = nx.barabasi_albert_graph(10, 3, seed=67, initial_graph=None)
nx.draw(G_hubs)
